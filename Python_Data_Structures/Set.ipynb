# %% [markdown]
# #### Python Sets
# Sets are unordered collection of data items. They store multiple items in a single variable. Set items are separated by commas and enclosed within curly brackets {}. Sets are unchangeable, meaning you cannot change items of the set once created. Sets do not contain duplicate items.
#
# ##### Example:

# %%
info = {"Carla", 19, False, 5.9, 19}
print(info)
# Out:
# {False, 'Carla', 19, 5.9}

# %% [markdown]
# Here we see that the items of set occur in random order and hence they cannot be accessed using index numbers. Also sets do not allow duplicate values.

# %% [markdown]
# ##### Let's try to create an empty set. Check using the type() function whether the type of your variable is a set

# %% [markdown]
# ##### For creating an empty set, we need to use 'set()'; if we use '{}', that will create a dictionary, not a set.

# %%
A = set()
type(A)
# Out:
# set

# %% [markdown]
# #### Accessing set items:
# Using a For loop\
# You can access items of set using a for loop.
#
# ##### Example:

# %%
info = {"Carla", 19, False, 5.9, 19}
for value in info:
    print(value)
# Out:
# False
# Carla
# 19
# 5.9

# %% [markdown]
# #### Joining Sets
# Sets in Python more or less work in the same way as sets in mathematics. We can perform operations like union and intersection on the sets just like in mathematics.
#
# #### I. union() and update():
# The union() and update() methods both combine the items from two sets. The union() method creates and returns a new set with all the items, while the update() method adds items to the existing set.
#
# ##### Example:

# %%
Cities  = {"Tokyo", "Madrid", "Dhaka", "Delhi"}
Cities2 = {"Tokyo", "Texas", "Kabul", "Madrid"}
Cities3 = Cities.union(Cities2)
print(Cities3)
# Out:
# {'Texas', 'Madrid', 'Dhaka', 'Delhi', 'Kabul', 'Tokyo'}

# %% [markdown]
# ##### When we use union(), the two sets become unchanged.

# %%
print(Cities)
print(Cities2)
# Out:
# {'Madrid', 'Delhi', 'Dhaka', 'Tokyo'}
# {'Madrid', 'Texas', 'Kabul', 'Tokyo'}

# %% [markdown]
# ##### When we use update(), the 'Cities' set is modified.

# %%
Cities  = {"Tokyo", "Madrid", "Dhaka", "Delhi"}
Cities2 = {"Tokyo", "Texas", "Kabul", "Madrid"}
Cities.update(Cities2)
print(Cities)
# Out:
# {'Texas', 'Madrid', 'Dhaka', 'Delhi', 'Kabul', 'Tokyo'}

# %%
print(Cities)
# Out:
# {'Texas', 'Madrid', 'Dhaka', 'Delhi', 'Kabul', 'Tokyo'}

# %% [markdown]
# #### II. intersection and intersection_update():
# The intersection() and intersection_update() methods prints only items that are similar to both the sets. The intersection() method returns a new set whereas intersection_update() method updates into the existing set from another set.
#
# ##### Example:

# %%
Cities  = {"Tokyo", "Madrid", "Dhaka", "Delhi"}
Cities2 = {"Tokyo", "Texas", "Kabul", "Madrid"}
Cities3 = Cities.intersection(Cities2)
print(Cities3)
# Out:
# {'Madrid', 'Tokyo'}

# %% [markdown]
# ##### Similarly, when we use intersection(), the two sets become unchanged.

# %%
print(Cities)
print(Cities2)
# Out:
# {'Madrid', 'Delhi', 'Dhaka', 'Tokyo'}
# {'Madrid', 'Texas', 'Kabul', 'Tokyo'}

# %% [markdown]
# ##### Similarly, when we use intersection_update(), the 'Cities' set is modified.

# %%
Cities  = {"Tokyo", "Madrid", "Dhaka", "Delhi"}
Cities2 = {"Tokyo", "Texas", "Kabul", "Madrid"}
Cities.intersection_update(Cities2)
print(Cities)
# Out:
# {'Madrid', 'Tokyo'}

# %%
print(Cities)
# Out:
# {'Madrid', 'Tokyo'}

# %% [markdown]
# #### III. symmetric_difference and symmetric_difference_update():
# The symmetric_difference() and symmetric_difference_update() methods show only the items that are unique to each set. The symmetric_difference() method returns a new set, while the symmetric_difference_update() method updates the existing set with the unique items from another set.
#
# ##### Example:

# %%
Cities  = {"Tokyo", "Madrid", "Dhaka", "Delhi"}
Cities2 = {"Tokyo", "Texas", "Kabul", "Madrid"}
Cities.symmetric_difference(Cities2)
print(Cities)
# Out:
# {'Madrid', 'Delhi', 'Dhaka', 'Tokyo'}

# %% [markdown]
# ##### And again, the two sets remain unchanged when we use symmetric_difference().

# %%
print(Cities)
print(Cities2)
# Out:
# {'Madrid', 'Delhi', 'Dhaka', 'Tokyo'}
# {'Madrid', 'Texas', 'Kabul', 'Tokyo'}

# %%
Cities  = {"Tokyo", "Madrid", "Dhaka", "Delhi"}
Cities2 = {"Tokyo", "Texas", "Kabul", "Madrid"}
Cities.symmetric_difference_update(Cities2)
print(Cities)
# Out:
# {'Texas', 'Dhaka', 'Delhi', 'Kabul'}

# %% [markdown]
# ##### Here,the two sets remain unchanged when we use symmetric_difference_update().

# %%
print(Cities)
# Out:
# {'Texas', 'Dhaka', 'Delhi', 'Kabul'}

# %% [markdown]
# #### IV. difference() and difference_update():
# The difference() and difference_update() methods prints only items that are only present in the original set and not in both the sets. The difference() method returns a new set whereas difference_update() method updates into the existing set from another set.
#
# ##### Example:

# %%
Cities  = {"Tokyo", "Madrid", "Dhaka", "Delhi"}
Cities2 = {"Tokyo", "Texas", "Kabul", "Madrid"}
Cities.difference(Cities2)
print(Cities)
# Out:
# {'Madrid', 'Delhi', 'Dhaka', 'Tokyo'}

# %% [markdown]
# #### Two sets remain unchanged when we use difference().

# %%
print(Cities)
print(Cities2)
# Out:
# {'Madrid', 'Delhi', 'Dhaka', 'Tokyo'}
# {'Madrid', 'Texas', 'Kabul', 'Tokyo'}

# %%
Cities = {"Tokyo", "Madrid", "Dhaka", "Delhi"}
Cities2 = {"Tokyo", "Texas", "Kabul", "Madrid"}
Cities.difference_update(Cities2)
print(Cities)
# Out:
# {'Delhi', 'Dhaka'}

# %% [markdown]
# #### The set "Cities" changes when we use difference_update().

# %%
print(Cities)
# Out:
# {'Delhi', 'Dhaka'}

# %% [markdown]
# #### Set Methods
# There are several in-built methods used for the manipulation of set.They are explained below
#
# isdisjoint():
# The isdisjoint() method checks if items of given set are present in another set. This method returns False if items are present, else it returns True.
#
# ##### Example:

# %%
Cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
Cities2 = {"Tokyo", "Seoul", "Kabul", "Madrid"}
print(Cities.isdisjoint(Cities2))
# Out:
# False

# %%
Cities = {"Dhaka", "Texas", "Berlin", "Delhi"}
Cities2 = {"Tokyo", "Seoul", "Kabul", "Madrid"}
print(Cities.isdisjoint(Cities2))
# Out:
# True

# %% [markdown]
# #### issuperset():
# The issuperset() method checks if all the items of a particular set are present in the original set. It returns True if all the items are present, else it returns False.
#
# ##### Example:

# %%
Cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
Cities2 = {"Seoul", "Kabul"}
print(Cities.issuperset(Cities2))
# Out:
# False

# %%
Cities3 = {"Tokyo", "Madrid", "Delhi"}
print(Cities.issuperset(Cities3))
# Out:
# True

# %% [markdown]
# #### issubset():
# The issubset() method checks if all the items of the original set are present in the particular set. It returns True if all the items are present, else it returns False.
#
# ##### cExample:

# %%
Cities = {"Tokyo", "Texas", "Berlin", "Dhaka"}
Cities2 = {"Dhaka", "Texas"}
print(Cities2.issubset(Cities))
# Out:
# True

# %% [markdown]
# #### add()
# If you want to add a single item to the set use the add() method.
#
# ##### Example:

# %%
Cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
Cities.add("Dhaka")
print(Cities)
# Out:
# {'Madrid', 'Dhaka', 'Berlin', 'Delhi', 'Tokyo'}

# %% [markdown]
# #### update()
# If you want to add more than one item, simply create another set or any other iterable object(list, tuple, dictionary), and use the update() method to add it into the existing set.
#
# ##### Example:

# %%
Cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
Cities2 = {"Dhaka", "Texas", "Seoul"}
Cities.update(Cities2)
print(Cities)
# Out:
# {'Berlin', 'Delhi', 'Texas', 'Tokyo', 'Madrid', 'Dhaka', 'Seoul'}

# %% [markdown]
# #### remove()/discard()
# We can use remove() and discard() methods to remove items form list.
#
# ##### Example :

# %%
Cities = {"Dhaka", "Madrid", "Berlin", "Delhi"}
Cities.remove("Dhaka")
print(Cities)
# Out:
# {'Berlin', 'Madrid', 'Delhi'}

# %% [markdown]
# The main difference between remove and discard is that, if we try to delete an item which is not present in set, then remove() raises an error, whereas discard() does not raise any error.
#
# ##### Example:

# %%
Cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
Cities.remove("Seoul")
print(cities)   # raises an error because "Seoul" is not in Cities
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 2
#       1 Cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
# ----> 2 Cities.remove("Seoul")
#       3 print(cities)   # raises an error because "Seoul" is not in Cities
#
# KeyError: 'Seoul'

# %%
Cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
Cities.discard("Seoul")
print(Cities)   
# If we use discard() and the element is not present in the set, the program will run without error occurring.
# Out:
# {'Berlin', 'Madrid', 'Delhi', 'Tokyo'}

# %% [markdown]
# #### pop()
# This method removes the last item of the set but the catch is that we don’t know which item gets popped as sets are unordered. However, you can access the popped item if you assign the pop() method to a variable.
#
# ##### Example:

# %%
Cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
item = Cities.pop()
print(Cities)
print(item)
# Out:
# {'Madrid', 'Delhi', 'Tokyo'}
# Berlin

# %% [markdown]
# #### del
# del is not a method, rather it is a keyword which deletes the set entirely.
#
# ##### Example:

# %%
Cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
del Cities

# %%
print(Cities)

# NameError: name 'Cities' is not defined. We get an error because our entire set has been deleted. and there is 
# And there is no variable called cities, which contains a set.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 print(Cities)
#       3 # NameError: name 'Cities' is not defined. We get an error because our entire set has been deleted. and there is
#       4 # And there is no variable called cities, which contains a set.
#
# NameError: name 'Cities' is not defined

# %% [markdown]
# #### clear():
# This method clears all items in the set and prints an empty set.
#
# ##### Example:

# %%
Cities = {"Dhaka", "Madrid", "Texas", "Delhi"}
Cities.clear()
print(Cities)
# Out:
# set()

# %% [markdown]
# #### Check if item exists
# You can also check if an item exists in the set or not.
#
# ##### Example

# %%
info = {"Dhaka", 19, True, 99}
if "Dhaka" in info:
    print("Dhaka is present.")
else:
    print("Dhaka is absent.")
# Out:
# Dhaka is present.
